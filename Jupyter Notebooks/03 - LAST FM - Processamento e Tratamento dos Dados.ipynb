# %%
# Importando bibliotecas

import os
import pandas as pd

# %%
# Definindo diretório

os.chdir(r"D:\Documents\Scripts\TCC\Hits\Dataset\Bases Originais\Lastfm")

# %%
# Escolhendo as colunas utilizadas do dataset Lastfm e criando um novo CSV

lastfm_df = pd.read_csv('lastfm.csv')

lastfm_df.rename(columns={'artist_mb': 'artist_final', 
                           'country_mb': 'country',
                           'tags_lastfm': 'genre'}, inplace=True)

seleciona_col = ['artist_final','country','genre']

lastfm_col = lastfm_df[seleciona_col]
lastfm_col['genre'] = lastfm_col['genre'].str.split(';').str[0]
lastfm_col.to_csv(r'D:\Documents\Scripts\TCC\Hits\Dataset\Bases Tratadas\Lastfm\FINAL_lastfm.csv', index=False)
# Out:
# C:\Users\maath\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (2,4,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-3-dffde979c5a8>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lastfm_col['genre'] = lastfm_col['genre'].str.split(';').str[0]

# %%
# Verificando como ficou o dataframe FINAL_lastfm

from Exploração_inicial import Descreve_Dataset, Dataset_Colunas_Nulos, Amostra_Dataset

os.chdir(r"D:\Documents\Scripts\TCC\Hits\Dataset\Bases Tratadas\Lastfm")

analise_df = pd.read_csv('FINAL_lastfm.csv')
Descreve_Dataset(analise_df)
Dataset_Colunas_Nulos(analise_df)
Amostra_Dataset(analise_df)

print ("A coluna artist_final apresenta "+ str(analise_df["artist_final"].unique().size) + " registros únicos.\n")
# Out:
# O dataset apresenta 19 variáveis (colunas) e 5520 registros.
#
# A seguir a listagem das colunas, seus tipos e seu nível de preenchimento:
# Index(['track', 'artist', 'uri', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit',
#        'sections', 'target'],
#       dtype='object')
#                      Tipo Nulos Nulos (%)
# track              object     0       0.0
# artist             object     0       0.0
# uri                object     0       0.0
# danceability      float64     0       0.0
# energy            float64     0       0.0
# key                 int64     0       0.0
# loudness          float64     0       0.0
# mode                int64     0       0.0
# speechiness       float64     0       0.0
# acousticness      float64     0       0.0
# instrumentalness  float64     0       0.0
# ...

# %%
# Excluindo as linhas com valores nulos 

os.chdir(r"D:\Documents\Scripts\TCC\Hits\Dataset\Bases Tratadas\Lastfm")

lastfm_df = pd.read_csv('FINAL_lastfm.csv')

lastfm_df.dropna(how="any", inplace=True)

lastfm_df.to_csv('FINAL_lastfm.csv', index=False)

# Verificando como ficou o dataframe FINAL_lastfm

from Exploração_inicial import Descreve_Dataset, Dataset_Colunas_Nulos, Amostra_Dataset

analise_df = pd.read_csv('FINAL_lastfm.csv')
Descreve_Dataset(analise_df)
Dataset_Colunas_Nulos(analise_df)
Amostra_Dataset(analise_df)

print ("A coluna artist_final apresenta "+ str(analise_df["artist_final"].unique().size) + " registros únicos.\n")
# Out:
# C:\Users\maath\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# O dataset apresenta 3 variáveis (colunas) e 194409 registros.
#
# A seguir a listagem das colunas, seus tipos e seu nível de preenchimento:
# Index(['artist_final', 'country', 'genre'], dtype='object')
#                 Tipo Nulos Nulos (%)
# artist_final  object     0       0.0
# country       object     0       0.0
# genre         object     0       0.0
# Amostra para verificar o formato de preenchimento das colunas:
#                            0               1                      2  \
# artist_final        Coldplay       Radiohead  Red Hot Chili Peppers
# country       United Kingdom  United Kingdom          United States
# genre                   rock     alternative                   rock
#
# ...

# %%
# Já sem os valores nulos, hora de tratar as linhas duplicadas

lastfm_df = pd.read_csv('FINAL_lastfm.csv')
duplicadas_df = lastfm_df[lastfm_df.duplicated()]
print("Linhas duplicadas exceto a primeira ocorrência:")
print(duplicadas_df)

lastfm_df.drop_duplicates(subset='artist_final', keep="first", inplace=True)

print(lastfm_df)

duplicadas_df = lastfm_df[lastfm_df.duplicated()]

print("Linhas duplicadas exceto a primeira ocorrência:")
print(duplicadas_df)

lastfm_df.to_csv('FINAL_lastfm.csv', index=False)
# Out:
# Linhas duplicadas exceto a primeira ocorrência:
#                    artist_final         country       genre
# 74                  Chris Brown   United States         rnb
# 75                  Chris Brown   United States         rnb
# 76                  Chris Brown   United States         rnb
# 509               John Williams   United States  Soundtrack
# 510               John Williams   United States  Soundtrack
# ...                         ...             ...         ...
# 193879                      DDT           Italy        rock
# 194018                   K.G.B.   United States   seen live
# 194296              The Numbers  United Kingdom        punk
# 194299  The Oscar Peterson Trio   United States        jazz
# 194340                     Urge  United Kingdom     screamo
#
# [2190 rows x 3 columns]
#                  artist_final         country               genre
# 0                    Coldplay  United Kingdom                rock
# ...

# %%
# Verificando como ficou o dataframe FINAL_lastfm

os.chdir(r"D:\Documents\Scripts\TCC\Hits\Dataset\Bases Tratadas\Lastfm")

from Exploração_inicial import Descreve_Dataset, Dataset_Colunas_Nulos, Amostra_Dataset

analise_df = pd.read_csv('FINAL_lastfm.csv')
Descreve_Dataset(analise_df)
Dataset_Colunas_Nulos(analise_df)
Amostra_Dataset(analise_df)

print ("A coluna artist_final apresenta "+ str(analise_df["artist_final"].unique().size) + " registros únicos.\n")
# Out:
# O dataset apresenta 3 variáveis (colunas) e 180961 registros.
#
# A seguir a listagem das colunas, seus tipos e seu nível de preenchimento:
# Index(['artist_final', 'country', 'genre'], dtype='object')
#                 Tipo Nulos Nulos (%)
# artist_final  object     0       0.0
# country       object     0       0.0
# genre         object     0       0.0
# Amostra para verificar o formato de preenchimento das colunas:
#                            0               1                      2  \
# artist_final        Coldplay       Radiohead  Red Hot Chili Peppers
# country       United Kingdom  United Kingdom          United States
# genre                   rock     alternative                   rock
#
#                           3              4
# artist_final        Rihanna         Eminem
# country       United States  United States
# genre                   pop            rap
# A coluna artist_final apresenta 180961 registros únicos.
